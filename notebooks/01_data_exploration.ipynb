# %% [markdown]
# # ARC-AGI Data Exploration
#
# Load and visualize ARC tasks.

# %%
import sys
sys.path.insert(0, '..')

from src.data_loader import load_tasks
from src.visualizer import show_task

# %%
tasks = load_tasks('training')
print(f'Loaded {len(tasks)} training tasks')
print(f'Example task ID: {tasks[0]["id"]}')

# %%
show_task(tasks[0])
